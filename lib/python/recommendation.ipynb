# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\krish\Projects\App Dev\greenthumbai\lib\python\recommendation.ipynb Cell 1 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/krish/Projects/App%20Dev/greenthumbai/lib/python/recommendation.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
#
# File c:\Users\krish\anaconda3\envs\recom\lib\site-packages\pandas\__init__.py:73
#      70 # let init-time option registration happen
#      71 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
# ---> 73 from pandas.core.api import (
#      74     # dtype
#      75     ArrowDtype,
#      76     Int8Dtype,
#      77     Int16Dtype,
#      78     Int32Dtype,
#      79     Int64Dtype,
#      80     UInt8Dtype,
#      81     UInt16Dtype,
#      82     UInt32Dtype,
#      83     UInt64Dtype,
#      84     Float32Dtype,
# ...

# %%
df = pd.read_csv("assets/plantinfo_clean.csv",encoding='unicode_escape')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\krish\Projects\App Dev\greenthumbai\lib\python\recommendation.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/krish/Projects/App%20Dev/greenthumbai/lib/python/recommendation.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> df = pd.read_csv("assets/plantinfo_clean.csv",encoding='unicode_escape')
#
# NameError: name 'pd' is not defined

# %%
df.head()
# Out:
#                  name                                    sowinstructions  \
# 0            Amaranth  Sow in garden. Sow seed at a depth approximate...
# 1            Angelica  Easy to grow. Sow in garden. Sow seed at a dep...
# 2  Artichokes (Globe)  Easy to grow. Sow in garden. Sow seed at a dep...
# 3           Asparagus  Easy to grow. Plant as crowns. Best planted at...
# 4       Asparagus Pea  Easy to grow. Sow in garden. Sow seed at a dep...
#
#                     spaceinstructions  \
# 0       Space plants: 20 inches apart
# 1       Space plants: 18 inches apart
# 2  Space plants: 63 - 79 inches apart
# 3   Space plants: 8 - 16 inches apart
# 4   Space plants: 8 - 10 inches apart
#
#                                  harvestinstructions  \
# 0                              Harvest in 7-8 weeks.
# 1  Harvest in approximately 18 months. Angelica a...
# 2                            Harvest in 42-57 weeks.
# 3  Harvest in 2-3 years. Plant 'crowns' to harves...
# ...

# %%
sunshine = input().strip()

# %%
weather = input().strip()

# %%
soil_condition = input().strip()

# %%
row_lis = df[(df["Sunshine"] == sunshine ) & (df["Weather"] == weather) & (df["Soil Conditions"] == soil_condition)].values

# %%
print(row_lis)
# Out:
# [['Asparagus Pea'
#   'Easy to grow. Sow in garden. Sow seed at a depth approximately three times the diameter of the seed. Best planted at soil temperatures between 59Â°F and 68Â°F. (Show Â°C/cm)'
#   'Space plants: 8 - 10 inches apart'
#   'Harvest in 8-11 weeks. Pick early, pick often.'
#   'Compatible with (can grow beside): Best grown in separate bed'
#   'Full sun to partial shade, well-drained soil. Prefers a pH of 6.5-7.5. Water regularly, but allow soil to dry out slightly between waterings. Fertilize every 2-3 weeks with a balanced fertilizer.'
#   'Cool weather, full sun, well-drained soil' 'full sun' 'cool weather'
#   'well-drained soil']
#  ['Beetroot'
#   'Easy to grow. Sow in garden. Sow seed at a depth approximately three times the diameter of the seed. Best planted at soil temperatures between 45Â°F and 77Â°F. (Show Â°C/cm)'
#   'Space plants: 8 - 12 inches apart' 'Harvest in 7-10 weeks.'
# ...
